# %%
# clingo default search
# !bash solver_lnps.sh a=10 t=6
# Out:
# clingo version 5.7.1
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_lnps.sh a=10 t=6 l=False
# Out:
# clingo version 5.7.1
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_lnps.sh a=10 t=6 l=False
# Out:
# clingo version 5.7.1
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_lnps.sh a=10 t=6 l=False
# Out:
# clingo version 5.7.1
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# Solving...
# Answer: 1
# ...
