# %%
# lnps solver
# !bash solver_lnps.sh a=10 t=6
# Out:
# heulingo version 0.2
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# c --------------------------------------------------------------------------------------
# c Finding an initial solution
# c --------------------------------------------------------------------------------------
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_lnps.sh a=10 t=6 l=True
# Out:
# heulingo version 0.2
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# c --------------------------------------------------------------------------------------
# c Finding an initial solution
# c --------------------------------------------------------------------------------------
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_lnps.sh a=10 t=6 l=True
# Out:
# heulingo version 0.2
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# c --------------------------------------------------------------------------------------
# c Finding an initial solution
# c --------------------------------------------------------------------------------------
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_lnps.sh a=10 t=6 l=True
# Out:
# heulingo version 0.2
# Reading from ...cheduling-rqtime/program_2/opt_lnps.lp ...
# c --------------------------------------------------------------------------------------
# c Finding an initial solution
# c --------------------------------------------------------------------------------------
# Solving...
# Answer: 1
# ...
