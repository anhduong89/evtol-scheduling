# %%
# !pwd
# Out:
# /Users/duong/Work-Documents/NMSU/NASA_ULI_2022/my-code-no-public/evtol-scheduling/trip-RQtime-formulation/240815-lns-solv-fleet-sch

# %%
# !bash run/solver_test.sh

# %%
# !clingo encoding/agent_path.lp
# Out:
# clingo version 5.6.2
# Reading from encoding/agent_path.lp
# encoding/agent_path.lp:9:26-34: info: operation undefined:
#   (speed*30)
#
# encoding/agent_path.lp:10:26-36: info: atom does not occur in any rule head:
#   edge(V,V)
#
# Solving...
# Answer: 1
# edge_w((crj,mbf),4,0) edge_w((mgt,mgt),4,0) edge_w((mgt,mbf),4,0) edge_w((tci,crj),4,0) edge_w((mbf,mbf),4,0) edge_w((crj,lbm),4,4) edge_w((mbf,lbm),4,4) edge_w((mbf,mgt),4,2) edge_w((mbf,lbm),4,2) edge_w((mbf,mbf),4,1) edge_w((mgt,mbf),4,6) edge_w((mgt,lbm),4,1) edge_w((lbm,mgt),4,6) edge_w((lbm,crj),4,5) agent_loc(0,mgt,0) agent_loc(1,crj,0) agent_loc(2,tci,0) agent_loc(3,mgt,0) agent_loc(4,mbf,0) total_passengers(4) agent_move(4,(mbf,mbf),0) agent_move(3,(mgt,mbf),0) agent_move(2,(tci,tci),0) agent_move(1,(crj,crj),0) agent_move(0,(mgt,mgt),0)
# SATISFIABLE
#
# Models       : 1+
# Calls        : 1
# Time         : 0.003s (Solving: 0.00s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.002s

# %%
# !bash run/solver_lnps.sh
# Out:
# heulingo version 0.2
# Reading from ...ns-solv-fleet-sch/encoding/opt_lnps.lp ...
# /Users/duong/Work-Documents/NMSU/NASA_ULI_2022/my-code-no-public/evtol-scheduling/trip-RQtime-formulation/240815-lns-solv-fleet-sch/encoding/compute_path.lp:66:1-20: info: no atoms over signature occur in program:
#   agent_move/3
#
# c --------------------------------------------------------------------------------------
# c Finding an initial solution
# c --------------------------------------------------------------------------------------
# Solving...
# Answer: 1
# agent_loc(0,mgt,0) agent_loc(1,crj,0) agent_loc(2,tci,0) agent_loc(3,mgt,0) agent_loc(4,mbf,0) edge_w((mgt,mgt),4,0) edge_w((mgt,mbf),4,0) edge_w((tci,crj),4,0) edge_w((mbf,mbf),4,0) edge_w((crj,mbf),4,0) edge_w((crj,lbm),4,4) edge_w((crj,tci),4,3) edge_w((mbf,mgt),4,4) edge_w((mbf,tci),8,2) edge_w((mbf,mbf),4,1) edge_w((mgt,crj),4,1)
# Optimization: -11
# Answer: 2
# ...

# %%
# !clingo instance/init.lp instance/mer_lmp.lp instance/network.lp instance/rq.lp encoding/path.lp
# Out:
# clingo version 5.6.2
# Reading from instance/init.lp ...
# Solving...
# Answer: 1
# ...

# %%
# !python3 solver/heulingo.py --heulingo-configuration=tsp benchmark/tsp/tsp.lp benchmark/tsp/instances/dom_rand_70_300_1155482584_3.lp benchmark/tsp/configs/random_N.lp -c n=3

# %%
# !clingo benchmark/tsp/tsp.lp benchmark/tsp/instances/dom_rand_70_300_1155482584_3.lp
# Out:
# *** ERROR: (clingo): 'benchmark/tsp/instances/dom_rand_70_300_1155482584_3.lp': could not open input file!
# *** Info : (clingo): Try '--help' for usage information
