# %%
import re
import numpy as np
import pandas as pd
import copy
import ast

# %%
def print_atom(data_raw, atom_pattern, nb_term, term_not_int_change, sort_order):
    out = []
    for p in range(0, len(atom_pattern)):
        data = re.sub(' ', '\n', data_raw)
        data = re.findall(atom_pattern[p], data)

        data = [re.sub("dl\(", "", i) for i in data]
        data = [re.sub("\(", ",", i) for i in data]
        data = [re.sub("\)", "", i) for i in data]
        data = [re.sub(",,", ",", i) for i in data]

        data = [i.split(",") for i in data]
        # print(data)
        data = [[int(i) if k not in term_not_int_change[p] else i for i, k in zip(j,range(0, nb_term[p]))] for j in data]
        # print(data)
        for s, r in zip(sort_order[p], range(0, len(sort_order[p]))):
            # reverse=reverse[p][r]
            # print(sort_order[p])
            # print(len(sort_order[p]))
            # print(data)
            # print(s)
            # print(data[0][s])
            data = sorted(data, key = lambda x:x[s])
            
        out = out+data
    # Name of the output text file
    output_file = 'output_sort.txt'

    # Open the text file in write mode
    with open(output_file, 'w') as file:
        # Iterate over each row in the list
        for row in out:
            # Convert each element to string and join them with tab separator
            line = '\t'.join(map(str, row))
            # Write the line to the text file
            file.write(line + '\n')

    print("Text file created successfully:", output_file)

# %%
df = pd.read_excel('atom_list.xlsx',skiprows=lambda x: x not in [0, 10, 6, 7] )
print(df)
# Out:
#    name                        atom                atom example  \
# 0   NaN           as(D, (V, V'), X)           as(0,(mbf,mgt),2)
# 1   NaN  dl(arrival_v(D, V, X), T )  dl(arrival_v(1,lbm,2),165)
# 2   NaN     dl(start_v(D, V, X), T)    dl(start_v(0,mbf,4),166)
#
#     atom pattern  number of terms term_not_convert sort_order  \
# 0         as\(.*                5        [0, 2, 3]     [4, 1]
# 1  dl\(arrival.*                5           [0, 2]     [3, 1]
# 2  dl\(start_v.*                5           [0, 2]      [3,1]
#
#    sort reserve order
# 0                 NaN
# 1                 NaN
# 2                 NaN

# %%
data_raw = '''dl(start_v(0,crj,3),11) dl(start_v(0,crj,4),11) dl(start_v(0,crj,5),11) dl(start_v(0,crj,6),11) dl(start_v(0,crj,7),11) dl(start_v(0,crj,8),11) dl(start_v(0,crj,9),11) dl(start_v(0,crj,10),11) dl(start_v(0,crj,11),11) dl(start_v(0,crj,12),11) dl(start_v(0,crj,13),11) dl(start_v(0,crj,14),11) dl(start_v(0,crj,15),11) dl(start_v(0,crj,16),11) dl(start_v(0,crj,17),11) dl(start_v(0,crj,18),11) dl(start_v(0,crj,19),11) dl(start_v(0,crj,20),11) dl(start_v(0,crj,21),11) dl(start_v(0,crj,22),11) dl(start_v(0,crj,23),11) dl(start_v(0,crj,24),11) dl(start_v(0,crj,25),11) dl(start_v(0,crj,26),12) dl(start_v(1,crj,25),7) dl(start_v(2,crj,0),0) dl(start_v(2,crj,1),0) dl(start_v(2,crj,2),0) dl(start_v(2,crj,3),0) dl(start_v(2,crj,4),0) dl(start_v(2,crj,5),0) dl(start_v(2,crj,6),0) dl(start_v(2,crj,7),0) dl(start_v(2,crj,8),0) dl(start_v(2,crj,9),0) dl(start_v(2,crj,10),1) dl(start_v(2,crj,14),13) dl(start_v(2,crj,15),13) dl(start_v(2,crj,16),13) dl(start_v(2,crj,17),13) dl(start_v(2,crj,18),13) dl(start_v(2,crj,19),13) dl(start_v(2,crj,20),13) dl(start_v(2,crj,21),13) dl(start_v(2,crj,22),13) dl(start_v(2,crj,23),13) dl(start_v(2,crj,24),13) dl(start_v(2,crj,25),13) dl(start_v(2,crj,26),13) dl(start_v(3,crj,3),8) dl(start_v(3,crj,4),9) dl(start_v(4,crj,0),0) dl(start_v(4,crj,1),0) dl(start_v(4,crj,2),0) dl(start_v(4,crj,3),1) dl(start_v(4,crj,7),13) dl(start_v(4,crj,8),13) dl(start_v(4,crj,9),13) dl(start_v(4,crj,10),13) dl(start_v(4,crj,11),13) dl(start_v(4,crj,12),13) dl(start_v(4,crj,13),13) dl(start_v(4,crj,14),13) dl(start_v(4,crj,15),13) dl(start_v(4,crj,16),13) dl(start_v(4,crj,17),13) dl(start_v(4,crj,18),13) dl(start_v(4,crj,19),13) dl(start_v(4,crj,20),13) dl(start_v(4,crj,21),13) dl(start_v(4,crj,22),13) dl(start_v(4,crj,23),13) dl(start_v(4,crj,24),13) dl(start_v(4,crj,25),13) dl(start_v(4,crj,26),13) dl(start_v(5,crj,3),13) dl(start_v(5,crj,4),13) dl(start_v(5,crj,5),13) dl(start_v(5,crj,6),13) dl(start_v(5,crj,7),13) dl(start_v(5,crj,8),13) dl(start_v(5,crj,9),13) dl(start_v(5,crj,10),13) dl(start_v(5,crj,11),13) dl(start_v(5,crj,12),13) dl(start_v(5,crj,13),13) dl(start_v(5,crj,14),13) dl(start_v(5,crj,15),13) dl(start_v(5,crj,16),13) dl(start_v(5,crj,17),13) dl(start_v(5,crj,18),13) dl(start_v(5,crj,19),13) dl(start_v(5,crj,20),13) dl(start_v(5,crj,21),13) dl(start_v(5,crj,22),13) dl(start_v(5,crj,23),13) dl(start_v(5,crj,24),13) dl(start_v(5,crj,25),13) dl(start_v(5,crj,26),13) dl(start_v(6,crj,0),0) dl(start_v(6,crj,1),0) dl(start_v(6,crj,2),1) dl(start_v(6,crj,4),7) dl(start_v(6,crj,6),12) dl(start_v(6,crj,7),12) dl(start_v(6,crj,8),12) dl(start_v(6,crj,9),12) dl(start_v(6,crj,10),12) dl(start_v(6,crj,11),12) dl(start_v(6,crj,12),12) dl(start_v(6,crj,13),12) dl(start_v(6,crj,14),12) dl(start_v(6,crj,15),12) dl(start_v(6,crj,16),12) dl(start_v(6,crj,17),12) dl(start_v(6,crj,18),12) dl(start_v(6,crj,19),12) dl(start_v(6,crj,20),12) dl(start_v(6,crj,21),12) dl(start_v(6,crj,22),12) dl(start_v(6,crj,23),12) dl(start_v(6,crj,24),12) dl(start_v(6,crj,25),12) dl(start_v(6,crj,26),12) dl(start_v(2,mbf,11),3) dl(start_v(2,mbf,12),5) dl(start_v(3,mbf,5),11) dl(start_v(3,mbf,6),11) dl(start_v(3,mbf,7),11) dl(start_v(3,mbf,8),11) dl(start_v(3,mbf,9),11) dl(start_v(3,mbf,10),11) dl(start_v(3,mbf,11),11) dl(start_v(3,mbf,12),11) dl(start_v(3,mbf,13),11) dl(start_v(3,mbf,14),11) dl(start_v(3,mbf,15),11) dl(start_v(3,mbf,16),11) dl(start_v(3,mbf,17),11) dl(start_v(3,mbf,18),11) dl(start_v(3,mbf,19),11) dl(start_v(3,mbf,20),11) dl(start_v(3,mbf,21),11) dl(start_v(3,mbf,22),11) dl(start_v(3,mbf,23),11) dl(start_v(3,mbf,24),11) dl(start_v(3,mbf,25),11) dl(start_v(3,mbf,26),12) dl(start_v(4,mbf,4),3) dl(start_v(4,mbf,5),5) dl(start_v(6,mbf,3),4) dl(start_v(6,mbf,5),10) dl(start_v(9,mbf,5),13) dl(start_v(9,mbf,6),13) dl(start_v(9,mbf,7),13) dl(start_v(9,mbf,8),13) dl(start_v(9,mbf,9),13) dl(start_v(9,mbf,10),13) dl(start_v(9,mbf,11),13) dl(start_v(9,mbf,12),13) dl(start_v(9,mbf,13),13) dl(start_v(9,mbf,14),13) dl(start_v(9,mbf,15),13) dl(start_v(9,mbf,16),13) dl(start_v(9,mbf,17),13) dl(start_v(9,mbf,18),13) dl(start_v(9,mbf,19),13) dl(start_v(9,mbf,20),13) dl(start_v(9,mbf,21),13) dl(start_v(9,mbf,22),13) dl(start_v(9,mbf,23),13) dl(start_v(9,mbf,24),13) dl(start_v(9,mbf,25),13) dl(start_v(9,mbf,26),13) dl(start_v(3,tci,0),0) dl(start_v(3,tci,1),0) dl(start_v(3,tci,2),2) dl(start_v(7,tci,0),0) dl(start_v(7,tci,1),0) dl(start_v(7,tci,2),2) dl(start_v(8,tci,0),0) dl(start_v(8,tci,1),0) dl(start_v(8,tci,2),0) dl(start_v(8,tci,3),2) dl(start_v(0,lbm,0),0) dl(start_v(0,lbm,1),2) dl(start_v(1,lbm,0),0) dl(start_v(1,lbm,1),0) dl(start_v(1,lbm,2),0) dl(start_v(1,lbm,3),0) dl(start_v(1,lbm,4),0) dl(start_v(1,lbm,5),0) dl(start_v(1,lbm,6),0) dl(start_v(1,lbm,7),0) dl(start_v(1,lbm,8),0) dl(start_v(1,lbm,9),0) dl(start_v(1,lbm,10),0) dl(start_v(1,lbm,11),0) dl(start_v(1,lbm,12),0) dl(start_v(1,lbm,13),0) dl(start_v(1,lbm,14),0) dl(start_v(1,lbm,15),0) dl(start_v(1,lbm,16),0) dl(start_v(1,lbm,17),0) dl(start_v(1,lbm,18),0) dl(start_v(1,lbm,19),0) dl(start_v(1,lbm,20),0) dl(start_v(1,lbm,21),0) dl(start_v(1,lbm,22),0) dl(start_v(1,lbm,23),0) dl(start_v(1,lbm,24),2) dl(start_v(5,lbm,2),9) dl(start_v(7,lbm,5),13) dl(start_v(7,lbm,6),13) dl(start_v(7,lbm,7),13) dl(start_v(7,lbm,8),13) dl(start_v(7,lbm,9),13) dl(start_v(7,lbm,10),13) dl(start_v(7,lbm,11),13) dl(start_v(7,lbm,12),13) dl(start_v(7,lbm,13),13) dl(start_v(7,lbm,14),13) dl(start_v(7,lbm,15),13) dl(start_v(7,lbm,16),13) dl(start_v(7,lbm,17),13) dl(start_v(7,lbm,18),13) dl(start_v(7,lbm,19),13) dl(start_v(7,lbm,20),13) dl(start_v(7,lbm,21),13) dl(start_v(7,lbm,22),13) dl(start_v(7,lbm,23),13) dl(start_v(7,lbm,24),13) dl(start_v(7,lbm,25),13) dl(start_v(7,lbm,26),13) dl(start_v(8,lbm,8),13) dl(start_v(8,lbm,9),13) dl(start_v(8,lbm,10),13) dl(start_v(8,lbm,11),13) dl(start_v(8,lbm,12),13) dl(start_v(8,lbm,13),13) dl(start_v(8,lbm,14),13) dl(start_v(8,lbm,15),13) dl(start_v(8,lbm,16),13) dl(start_v(8,lbm,17),13) dl(start_v(8,lbm,18),13) dl(start_v(8,lbm,19),13) dl(start_v(8,lbm,20),13) dl(start_v(8,lbm,21),13) dl(start_v(8,lbm,22),13) dl(start_v(8,lbm,23),13) dl(start_v(8,lbm,24),13) dl(start_v(8,lbm,25),13) dl(start_v(8,lbm,26),13) dl(start_v(9,lbm,2),7) dl(start_v(9,lbm,3),7) dl(start_v(9,lbm,4),9) dl(start_v(0,mgt,2),8) dl(start_v(1,mgt,26),11) dl(start_v(2,mgt,13),10) dl(start_v(4,mgt,6),10) dl(start_v(5,mgt,0),0) dl(start_v(5,mgt,1),2) dl(start_v(7,mgt,3),6) dl(start_v(7,mgt,4),8) dl(start_v(8,mgt,4),6) dl(start_v(8,mgt,5),6) dl(start_v(8,mgt,6),6) dl(start_v(8,mgt,7),8) dl(start_v(9,mgt,0),0) dl(start_v(9,mgt,1),2) dl(arrival_v(0,lbm,1),0) dl(arrival_v(0,mgt,2),7) dl(arrival_v(0,crj,3),11) dl(arrival_v(0,crj,4),11) dl(arrival_v(0,crj,5),11) dl(arrival_v(0,crj,6),11) dl(arrival_v(0,crj,7),11) dl(arrival_v(0,crj,8),11) dl(arrival_v(0,crj,9),11) dl(arrival_v(0,crj,10),11) dl(arrival_v(0,crj,11),11) dl(arrival_v(0,crj,12),11) dl(arrival_v(0,crj,13),11) dl(arrival_v(0,crj,14),11) dl(arrival_v(0,crj,15),11) dl(arrival_v(0,crj,16),11) dl(arrival_v(0,crj,17),11) dl(arrival_v(0,crj,18),11) dl(arrival_v(0,crj,19),11) dl(arrival_v(0,crj,20),11) dl(arrival_v(0,crj,21),11) dl(arrival_v(0,crj,22),11) dl(arrival_v(0,crj,23),11) dl(arrival_v(0,crj,24),11) dl(arrival_v(0,crj,25),11) dl(arrival_v(0,crj,26),11) dl(arrival_v(0,mgt,27),15) dl(arrival_v(1,lbm,1),0) dl(arrival_v(1,lbm,2),0) dl(arrival_v(1,lbm,3),0) dl(arrival_v(1,lbm,4),0) dl(arrival_v(1,lbm,5),0) dl(arrival_v(1,lbm,6),0) dl(arrival_v(1,lbm,7),0) dl(arrival_v(1,lbm,8),0) dl(arrival_v(1,lbm,9),0) dl(arrival_v(1,lbm,10),0) dl(arrival_v(1,lbm,11),0) dl(arrival_v(1,lbm,12),0) dl(arrival_v(1,lbm,13),0) dl(arrival_v(1,lbm,14),0) dl(arrival_v(1,lbm,15),0) dl(arrival_v(1,lbm,16),0) dl(arrival_v(1,lbm,17),0) dl(arrival_v(1,lbm,18),0) dl(arrival_v(1,lbm,19),0) dl(arrival_v(1,lbm,20),0) dl(arrival_v(1,lbm,21),0) dl(arrival_v(1,lbm,22),0) dl(arrival_v(1,lbm,23),0) dl(arrival_v(1,lbm,24),0) dl(arrival_v(1,crj,25),6) dl(arrival_v(1,mgt,26),10) dl(arrival_v(1,crj,27),14) dl(arrival_v(2,crj,1),0) dl(arrival_v(2,crj,2),0) dl(arrival_v(2,crj,3),0) dl(arrival_v(2,crj,4),0) dl(arrival_v(2,crj,5),0) dl(arrival_v(2,crj,6),0) dl(arrival_v(2,crj,7),0) dl(arrival_v(2,crj,8),0) dl(arrival_v(2,crj,9),0) dl(arrival_v(2,crj,10),0) dl(arrival_v(2,mbf,11),3) dl(arrival_v(2,mbf,12),3) dl(arrival_v(2,mgt,13),9) dl(arrival_v(2,crj,14),13) dl(arrival_v(2,crj,15),13) dl(arrival_v(2,crj,16),13) dl(arrival_v(2,crj,17),13) dl(arrival_v(2,crj,18),13) dl(arrival_v(2,crj,19),13) dl(arrival_v(2,crj,20),13) dl(arrival_v(2,crj,21),13) dl(arrival_v(2,crj,22),13) dl(arrival_v(2,crj,23),13) dl(arrival_v(2,crj,24),13) dl(arrival_v(2,crj,25),13) dl(arrival_v(2,crj,26),13) dl(arrival_v(2,crj,27),13) dl(arrival_v(3,tci,1),0) dl(arrival_v(3,tci,2),0) dl(arrival_v(3,crj,3),8) dl(arrival_v(3,crj,4),8) dl(arrival_v(3,mbf,5),11) dl(arrival_v(3,mbf,6),11) dl(arrival_v(3,mbf,7),11) dl(arrival_v(3,mbf,8),11) dl(arrival_v(3,mbf,9),11) dl(arrival_v(3,mbf,10),11) dl(arrival_v(3,mbf,11),11) dl(arrival_v(3,mbf,12),11) dl(arrival_v(3,mbf,13),11) dl(arrival_v(3,mbf,14),11) dl(arrival_v(3,mbf,15),11) dl(arrival_v(3,mbf,16),11) dl(arrival_v(3,mbf,17),11) dl(arrival_v(3,mbf,18),11) dl(arrival_v(3,mbf,19),11) dl(arrival_v(3,mbf,20),11) dl(arrival_v(3,mbf,21),11) dl(arrival_v(3,mbf,22),11) dl(arrival_v(3,mbf,23),11) dl(arrival_v(3,mbf,24),11) dl(arrival_v(3,mbf,25),11) dl(arrival_v(3,mbf,26),11) dl(arrival_v(3,crj,27),14) dl(arrival_v(4,crj,1),0) dl(arrival_v(4,crj,2),0) dl(arrival_v(4,crj,3),0) dl(arrival_v(4,mbf,4),3) dl(arrival_v(4,mbf,5),3) dl(arrival_v(4,mgt,6),9) dl(arrival_v(4,crj,7),13) dl(arrival_v(4,crj,8),13) dl(arrival_v(4,crj,9),13) dl(arrival_v(4,crj,10),13) dl(arrival_v(4,crj,11),13) dl(arrival_v(4,crj,12),13) dl(arrival_v(4,crj,13),13) dl(arrival_v(4,crj,14),13) dl(arrival_v(4,crj,15),13) dl(arrival_v(4,crj,16),13) dl(arrival_v(4,crj,17),13) dl(arrival_v(4,crj,18),13) dl(arrival_v(4,crj,19),13) dl(arrival_v(4,crj,20),13) dl(arrival_v(4,crj,21),13) dl(arrival_v(4,crj,22),13) dl(arrival_v(4,crj,23),13) dl(arrival_v(4,crj,24),13) dl(arrival_v(4,crj,25),13) dl(arrival_v(4,crj,26),13) dl(arrival_v(4,crj,27),13) dl(arrival_v(5,mgt,1),0) dl(arrival_v(5,lbm,2),7) dl(arrival_v(5,crj,3),13) dl(arrival_v(5,crj,4),13) dl(arrival_v(5,crj,5),13) dl(arrival_v(5,crj,6),13) dl(arrival_v(5,crj,7),13) dl(arrival_v(5,crj,8),13) dl(arrival_v(5,crj,9),13) dl(arrival_v(5,crj,10),13) dl(arrival_v(5,crj,11),13) dl(arrival_v(5,crj,12),13) dl(arrival_v(5,crj,13),13) dl(arrival_v(5,crj,14),13) dl(arrival_v(5,crj,15),13) dl(arrival_v(5,crj,16),13) dl(arrival_v(5,crj,17),13) dl(arrival_v(5,crj,18),13) dl(arrival_v(5,crj,19),13) dl(arrival_v(5,crj,20),13) dl(arrival_v(5,crj,21),13) dl(arrival_v(5,crj,22),13) dl(arrival_v(5,crj,23),13) dl(arrival_v(5,crj,24),13) dl(arrival_v(5,crj,25),13) dl(arrival_v(5,crj,26),13) dl(arrival_v(5,crj,27),13) dl(arrival_v(6,crj,1),0) dl(arrival_v(6,crj,2),0) dl(arrival_v(6,mbf,3),3) dl(arrival_v(6,crj,4),6) dl(arrival_v(6,mbf,5),9) dl(arrival_v(6,crj,6),12) dl(arrival_v(6,crj,7),12) dl(arrival_v(6,crj,8),12) dl(arrival_v(6,crj,9),12) dl(arrival_v(6,crj,10),12) dl(arrival_v(6,crj,11),12) dl(arrival_v(6,crj,12),12) dl(arrival_v(6,crj,13),12) dl(arrival_v(6,crj,14),12) dl(arrival_v(6,crj,15),12) dl(arrival_v(6,crj,16),12) dl(arrival_v(6,crj,17),12) dl(arrival_v(6,crj,18),12) dl(arrival_v(6,crj,19),12) dl(arrival_v(6,crj,20),12) dl(arrival_v(6,crj,21),12) dl(arrival_v(6,crj,22),12) dl(arrival_v(6,crj,23),12) dl(arrival_v(6,crj,24),12) dl(arrival_v(6,crj,25),12) dl(arrival_v(6,crj,26),12) dl(arrival_v(6,crj,27),12) dl(arrival_v(7,tci,1),0) dl(arrival_v(7,tci,2),0) dl(arrival_v(7,mgt,3),6) dl(arrival_v(7,mgt,4),6) dl(arrival_v(7,lbm,5),13) dl(arrival_v(7,lbm,6),13) dl(arrival_v(7,lbm,7),13) dl(arrival_v(7,lbm,8),13) dl(arrival_v(7,lbm,9),13) dl(arrival_v(7,lbm,10),13) dl(arrival_v(7,lbm,11),13) dl(arrival_v(7,lbm,12),13) dl(arrival_v(7,lbm,13),13) dl(arrival_v(7,lbm,14),13) dl(arrival_v(7,lbm,15),13) dl(arrival_v(7,lbm,16),13) dl(arrival_v(7,lbm,17),13) dl(arrival_v(7,lbm,18),13) dl(arrival_v(7,lbm,19),13) dl(arrival_v(7,lbm,20),13) dl(arrival_v(7,lbm,21),13) dl(arrival_v(7,lbm,22),13) dl(arrival_v(7,lbm,23),13) dl(arrival_v(7,lbm,24),13) dl(arrival_v(7,lbm,25),13) dl(arrival_v(7,lbm,26),13) dl(arrival_v(7,lbm,27),13) dl(arrival_v(8,tci,1),0) dl(arrival_v(8,tci,2),0) dl(arrival_v(8,tci,3),0) dl(arrival_v(8,mgt,4),6) dl(arrival_v(8,mgt,5),6) dl(arrival_v(8,mgt,6),6) dl(arrival_v(8,mgt,7),6) dl(arrival_v(8,lbm,8),13) dl(arrival_v(8,lbm,9),13) dl(arrival_v(8,lbm,10),13) dl(arrival_v(8,lbm,11),13) dl(arrival_v(8,lbm,12),13) dl(arrival_v(8,lbm,13),13) dl(arrival_v(8,lbm,14),13) dl(arrival_v(8,lbm,15),13) dl(arrival_v(8,lbm,16),13) dl(arrival_v(8,lbm,17),13) dl(arrival_v(8,lbm,18),13) dl(arrival_v(8,lbm,19),13) dl(arrival_v(8,lbm,20),13) dl(arrival_v(8,lbm,21),13) dl(arrival_v(8,lbm,22),13) dl(arrival_v(8,lbm,23),13) dl(arrival_v(8,lbm,24),13) dl(arrival_v(8,lbm,25),13) dl(arrival_v(8,lbm,26),13) dl(arrival_v(8,lbm,27),13) dl(arrival_v(9,mgt,1),0) dl(arrival_v(9,lbm,2),7) dl(arrival_v(9,lbm,3),7) dl(arrival_v(9,lbm,4),7) dl(arrival_v(9,mbf,5),13) dl(arrival_v(9,mbf,6),13) dl(arrival_v(9,mbf,7),13) dl(arrival_v(9,mbf,8),13) dl(arrival_v(9,mbf,9),13) dl(arrival_v(9,mbf,10),13) dl(arrival_v(9,mbf,11),13) dl(arrival_v(9,mbf,12),13) dl(arrival_v(9,mbf,13),13) dl(arrival_v(9,mbf,14),13) dl(arrival_v(9,mbf,15),13) dl(arrival_v(9,mbf,16),13) dl(arrival_v(9,mbf,17),13) dl(arrival_v(9,mbf,18),13) dl(arrival_v(9,mbf,19),13) dl(arrival_v(9,mbf,20),13) dl(arrival_v(9,mbf,21),13) dl(arrival_v(9,mbf,22),13) dl(arrival_v(9,mbf,23),13) dl(arrival_v(9,mbf,24),13) dl(arrival_v(9,mbf,25),13) dl(arrival_v(9,mbf,26),13) dl(arrival_v(9,mbf,27),13) dl(arrival_v(0,lbm,0),0) dl(arrival_v(1,lbm,0),0) dl(arrival_v(2,crj,0),0) dl(arrival_v(3,tci,0),0) dl(arrival_v(4,crj,0),0) dl(arrival_v(5,mgt,0),0) dl(arrival_v(6,crj,0),0) dl(arrival_v(7,tci,0),0) dl(arrival_v(8,tci,0),0) dl(arrival_v(9,mgt,0),0) as(0,(lbm,lbm),0) as(1,(lbm,lbm),0) as(2,(crj,crj),0) as(3,(tci,tci),0) as(4,(crj,crj),0) as(5,(mgt,mgt),0) as(6,(crj,crj),0) as(7,(tci,tci),0) as(8,(tci,tci),0) as(9,(mgt,mgt),0) as(0,(lbm,mgt),1) as(0,(mgt,crj),2) as(0,(crj,crj),3) as(0,(crj,crj),4) as(0,(crj,crj),5) as(0,(crj,crj),6) as(0,(crj,crj),7) as(0,(crj,crj),8) as(0,(crj,crj),9) as(0,(crj,crj),10) as(0,(crj,crj),11) as(0,(crj,crj),12) as(0,(crj,crj),13) as(0,(crj,crj),14) as(0,(crj,crj),15) as(0,(crj,crj),16) as(0,(crj,crj),17) as(0,(crj,crj),18) as(0,(crj,crj),19) as(0,(crj,crj),20) as(0,(crj,crj),21) as(0,(crj,crj),22) as(0,(crj,crj),23) as(0,(crj,crj),24) as(0,(crj,crj),25) as(0,(crj,mgt),26) as(1,(lbm,lbm),1) as(1,(lbm,lbm),2) as(1,(lbm,lbm),3) as(1,(lbm,lbm),4) as(1,(lbm,lbm),5) as(1,(lbm,lbm),6) as(1,(lbm,lbm),7) as(1,(lbm,lbm),8) as(1,(lbm,lbm),9) as(1,(lbm,lbm),10) as(1,(lbm,lbm),11) as(1,(lbm,lbm),12) as(1,(lbm,lbm),13) as(1,(lbm,lbm),14) as(1,(lbm,lbm),15) as(1,(lbm,lbm),16) as(1,(lbm,lbm),17) as(1,(lbm,lbm),18) as(1,(lbm,lbm),19) as(1,(lbm,lbm),20) as(1,(lbm,lbm),21) as(1,(lbm,lbm),22) as(1,(lbm,lbm),23) as(1,(lbm,crj),24) as(1,(crj,mgt),25) as(1,(mgt,crj),26) as(2,(crj,crj),1) as(2,(crj,crj),2) as(2,(crj,crj),3) as(2,(crj,crj),4) as(2,(crj,crj),5) as(2,(crj,crj),6) as(2,(crj,crj),7) as(2,(crj,crj),8) as(2,(crj,crj),9) as(2,(crj,mbf),10) as(2,(mbf,mbf),11) as(2,(mbf,mgt),12) as(2,(mgt,crj),13) as(2,(crj,crj),14) as(2,(crj,crj),15) as(2,(crj,crj),16) as(2,(crj,crj),17) as(2,(crj,crj),18) as(2,(crj,crj),19) as(2,(crj,crj),20) as(2,(crj,crj),21) as(2,(crj,crj),22) as(2,(crj,crj),23) as(2,(crj,crj),24) as(2,(crj,crj),25) as(2,(crj,crj),26) as(3,(tci,tci),1) as(3,(tci,crj),2) as(3,(crj,crj),3) as(3,(crj,mbf),4) as(3,(mbf,mbf),5) as(3,(mbf,mbf),6) as(3,(mbf,mbf),7) as(3,(mbf,mbf),8) as(3,(mbf,mbf),9) as(3,(mbf,mbf),10) as(3,(mbf,mbf),11) as(3,(mbf,mbf),12) as(3,(mbf,mbf),13) as(3,(mbf,mbf),14) as(3,(mbf,mbf),15) as(3,(mbf,mbf),16) as(3,(mbf,mbf),17) as(3,(mbf,mbf),18) as(3,(mbf,mbf),19) as(3,(mbf,mbf),20) as(3,(mbf,mbf),21) as(3,(mbf,mbf),22) as(3,(mbf,mbf),23) as(3,(mbf,mbf),24) as(3,(mbf,mbf),25) as(3,(mbf,crj),26) as(4,(crj,crj),1) as(4,(crj,crj),2) as(4,(crj,mbf),3) as(4,(mbf,mbf),4) as(4,(mbf,mgt),5) as(4,(mgt,crj),6) as(4,(crj,crj),7) as(4,(crj,crj),8) as(4,(crj,crj),9) as(4,(crj,crj),10) as(4,(crj,crj),11) as(4,(crj,crj),12) as(4,(crj,crj),13) as(4,(crj,crj),14) as(4,(crj,crj),15) as(4,(crj,crj),16) as(4,(crj,crj),17) as(4,(crj,crj),18) as(4,(crj,crj),19) as(4,(crj,crj),20) as(4,(crj,crj),21) as(4,(crj,crj),22) as(4,(crj,crj),23) as(4,(crj,crj),24) as(4,(crj,crj),25) as(4,(crj,crj),26) as(5,(mgt,lbm),1) as(5,(lbm,crj),2) as(5,(crj,crj),3) as(5,(crj,crj),4) as(5,(crj,crj),5) as(5,(crj,crj),6) as(5,(crj,crj),7) as(5,(crj,crj),8) as(5,(crj,crj),9) as(5,(crj,crj),10) as(5,(crj,crj),11) as(5,(crj,crj),12) as(5,(crj,crj),13) as(5,(crj,crj),14) as(5,(crj,crj),15) as(5,(crj,crj),16) as(5,(crj,crj),17) as(5,(crj,crj),18) as(5,(crj,crj),19) as(5,(crj,crj),20) as(5,(crj,crj),21) as(5,(crj,crj),22) as(5,(crj,crj),23) as(5,(crj,crj),24) as(5,(crj,crj),25) as(5,(crj,crj),26) as(6,(crj,crj),1) as(6,(crj,mbf),2) as(6,(mbf,crj),3) as(6,(crj,mbf),4) as(6,(mbf,crj),5) as(6,(crj,crj),6) as(6,(crj,crj),7) as(6,(crj,crj),8) as(6,(crj,crj),9) as(6,(crj,crj),10) as(6,(crj,crj),11) as(6,(crj,crj),12) as(6,(crj,crj),13) as(6,(crj,crj),14) as(6,(crj,crj),15) as(6,(crj,crj),16) as(6,(crj,crj),17) as(6,(crj,crj),18) as(6,(crj,crj),19) as(6,(crj,crj),20) as(6,(crj,crj),21) as(6,(crj,crj),22) as(6,(crj,crj),23) as(6,(crj,crj),24) as(6,(crj,crj),25) as(6,(crj,crj),26) as(7,(tci,tci),1) as(7,(tci,mgt),2) as(7,(mgt,mgt),3) as(7,(mgt,lbm),4) as(7,(lbm,lbm),5) as(7,(lbm,lbm),6) as(7,(lbm,lbm),7) as(7,(lbm,lbm),8) as(7,(lbm,lbm),9) as(7,(lbm,lbm),10) as(7,(lbm,lbm),11) as(7,(lbm,lbm),12) as(7,(lbm,lbm),13) as(7,(lbm,lbm),14) as(7,(lbm,lbm),15) as(7,(lbm,lbm),16) as(7,(lbm,lbm),17) as(7,(lbm,lbm),18) as(7,(lbm,lbm),19) as(7,(lbm,lbm),20) as(7,(lbm,lbm),21) as(7,(lbm,lbm),22) as(7,(lbm,lbm),23) as(7,(lbm,lbm),24) as(7,(lbm,lbm),25) as(7,(lbm,lbm),26) as(8,(tci,tci),1) as(8,(tci,tci),2) as(8,(tci,mgt),3) as(8,(mgt,mgt),4) as(8,(mgt,mgt),5) as(8,(mgt,mgt),6) as(8,(mgt,lbm),7) as(8,(lbm,lbm),8) as(8,(lbm,lbm),9) as(8,(lbm,lbm),10) as(8,(lbm,lbm),11) as(8,(lbm,lbm),12) as(8,(lbm,lbm),13) as(8,(lbm,lbm),14) as(8,(lbm,lbm),15) as(8,(lbm,lbm),16) as(8,(lbm,lbm),17) as(8,(lbm,lbm),18) as(8,(lbm,lbm),19) as(8,(lbm,lbm),20) as(8,(lbm,lbm),21) as(8,(lbm,lbm),22) as(8,(lbm,lbm),23) as(8,(lbm,lbm),24) as(8,(lbm,lbm),25) as(8,(lbm,lbm),26) as(9,(mgt,lbm),1) as(9,(lbm,lbm),2) as(9,(lbm,lbm),3) as(9,(lbm,mbf),4) as(9,(mbf,mbf),5) as(9,(mbf,mbf),6) as(9,(mbf,mbf),7) as(9,(mbf,mbf),8) as(9,(mbf,mbf),9) as(9,(mbf,mbf),10) as(9,(mbf,mbf),11) as(9,(mbf,mbf),12) as(9,(mbf,mbf),13) as(9,(mbf,mbf),14) as(9,(mbf,mbf),15) as(9,(mbf,mbf),16) as(9,(mbf,mbf),17) as(9,(mbf,mbf),18) as(9,(mbf,mbf),19) as(9,(mbf,mbf),20) as(9,(mbf,mbf),21) as(9,(mbf,mbf),22) as(9,(mbf,mbf),23) as(9,(mbf,mbf),24) as(9,(mbf,mbf),25) as(9,(mbf,mbf),26) as_rq(4,1,3) as_rq(7,135,2) as_rq(5,223,1) as_rq(9,223,1) revenue(2,1) revenue(1,135) revenue(8,223)'''


choose_atom_row = [i for i in range(0, len(df))]
atom_pattern=[df.loc[i, 'atom pattern'] for i in choose_atom_row]
nb_term = [df.loc[i, 'number of terms'] for i in choose_atom_row]
term_int_not_change = [ast.literal_eval(df.loc[i, 'term_not_convert']) for i in choose_atom_row]
# reverse= [l_reverse[i] for i in choose_atom_row]
sort_order= [ast.literal_eval(df.loc[i, 'sort_order']) for i in choose_atom_row]

print_atom(data_raw, atom_pattern, nb_term, term_int_not_change, sort_order)
# Out:
# Text file created successfully: output_sort.txt
