# %%
# !bash solver_lnps.sh a=5
# Out:
# clingo version 5.6.2
# Reading from ...ic/evtol-scheduling-rqtime/opt_lnps.lp ...
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_lnps.sh a=100 t=12
# Out:
# clingo version 5.6.2
# Reading from ...-sch/encoding-to-Mutsuroni/opt_lnps.lp ...
# Solving...
# Answer: 1
# ...
