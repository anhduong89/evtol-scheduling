# %%
# !bash solver_NY.sh
# Out:
# clingo-dl version 1.4.0
# Reading from cp_path.lp ...
# opt.lp:23:1-12: info: no atoms over signature occur in program:
#   dl/2
#
# Solving...
# Answer: 1
# ...

# %%
# !bash solver_NY.sh s=3 a=3
# Out:
# clingo-dl version 1.4.0
# Reading from cp_path.lp ...
# opt.lp:23:1-12: info: no atoms over signature occur in program:
#   dl/2
#
# Solving...
# Answer: 1
# ...
